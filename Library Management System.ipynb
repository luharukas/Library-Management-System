# %%
import tkinter as tk
from tkinter.ttk import *
from tkinter import *
import time
import os
from PIL import ImageTk, Image
import random
from datetime import date
import datetime
import smtplib
from tkinter import messagebox
import mysql.connector
conn = mysql.connector.connect(user='root', password='rishabh@', host='127.0.0.1', database='mydatabase')
cursor = conn.cursor()

window = tk.Tk()
window.state('zoomed')
window.rowconfigure(0,weight=1)
window.columnconfigure(0,weight=1)

frame1 = tk.Frame(window)
frame2 = tk.Frame(window)
frame3 = tk.Frame(window)
frame4 = tk.Frame(window)
frame5 = tk.Frame(window)
frame6 = tk.Frame(window)
frame7 = tk.Frame(window)
frame8 = tk.Frame(window)
frame9 = tk.Frame(window)
frame10 =tk.Frame(window)
frame11=tk.Frame(window)
frame12=tk.Frame(window)
frame13=tk.Frame(window)
frame14=tk.Frame(window)
frame15=tk.Frame(window)
frame16=tk.Frame(window)
frame17=tk.Frame(window)
frame18=tk.Frame(window)
frame19=tk.Frame(window)
frame20=tk.Frame(window)
name_var=tk.StringVar() 
passw_var=tk.StringVar()
newpass=tk.StringVar()
rnewpass=tk.StringVar()
otp=tk.StringVar()
userid=tk.StringVar()
bookid=tk.StringVar()
for frame in (frame1,frame2,frame3,frame4,frame5,frame6,frame7,frame8,frame9,frame10,frame11,frame12,frame13,frame14,frame15,frame16,frame17,frame18,frame19,frame20):
    frame.grid(row=0,column=0,sticky="nsew")

def payself():
        name=name_var.get()
        add1=0
        add2=0
        no=frame192_entry.get()
        for i in range(0,16,2):
            c1=int(no[i])*2
            if c1>=10:
                c1=c1-9
            add1=add1+c1
        for i in range(1,16,2):
            add2=add2+int(no[i])
        if (add1+add2)%10==0:
            Update3="Update user set payfine='%s' where USER_ID='%s' " %(0,name)
            cursor.execute(Update3)
            conn.commit()
            messagebox.askokcancel("Information","NO DUE")
        else:
            messagebox.askokcancel("Information","CARD NO WRONG")
        
image19=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame5.jpg")
image19=image19.resize((1530,800),Image.ANTIALIAS)
img19 = ImageTk.PhotoImage(image19)
panel19 = tk.Label(frame19, image = img19)
panel19.place(relx=0,rely=0)
frame191_label=tk.Label(frame19,text="ENTER YOUR CARD NO",width=20,height=2,bg="pink")
frame191_label.place(relx=0.5,rely=0.3)
frame192_entry=tk.Entry(frame19,width=30,borderwidth=8)
frame192_entry.place(relx=0.6,rely=0.3)
frame193_button=tk.Button(frame19,text="CHECK AND PAY",width=15,height=2,command=payself).place(relx=0.4,rely=0.5)
back_button19=tk.Button(frame19,text="BACK",width=5,height=2,command=lambda:show_frame(frame17))
back_button19.place(relx=0.5,rely=0.5)

def logout():
    name_var.set("")
    passw_var.set("")
    show_frame(frame1)
    
    
def pay():
        user=frame162_entry.get()
        Update3="Update user set payfine='%s' where USER_ID='%s' " %(0,user)
        cursor.execute(Update3)
        conn.commit()
        messagebox.askokcancel("Information","no due")
def payfine():
    user=frame162_entry.get()
    cursor.execute("SELECT * from user WHERE USER_ID = '%s' "%(user))
    t=(cursor.fetchall())
    if t==[]:
        messagebox.askokcancel("Information","No Record exists")
    else:
        frame11_button=tk.Button(frame16,text="PAY",width=10,height=2,command=pay).place(relx=0.45,rely=0.4)
        frame111_label=tk.Label(frame16,text="DUE AMOUNT",width=20,height=2,bg="pink").place(relx=0.45,rely=0.2)
        frame115_label=tk.Label(frame16,text=t[0][13],width=20,height=2,bg="pink").place(relx=0.45,rely=0.3)
        

        
image16=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame5.jpg")
image16=image16.resize((1530,800),Image.ANTIALIAS)
img16 = ImageTk.PhotoImage(image16)
panel16 = tk.Label(frame16, image = img16)
panel16.place(relx=0,rely=0)
frame161_label=tk.Label(frame16,text="USER_ID",width=20,height=2,bg="pink").place(relx=0.25,rely=0.2)
frame162_entry=tk.Entry(frame16,width=20,borderwidth=10)
frame162_entry.place(relx=0.25,rely=0.3)
frame163_button=tk.Button(frame16,text="SHOW DUES",width=10,height=2,command=payfine).place(relx=0.25,rely=0.4)
back_button16=tk.Button(frame16,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button16.place(relx=0.5,rely=0.5)

def renew():
    today = date.today()
    returndate = today + datetime.timedelta(days = 15)
    book=bookid.get()
    cursor.execute("SELECT * from user WHERE BOOK1 = '%s' "%(book))
    t=(cursor.fetchall())
    if  t==[]:
        cursor.execute("SELECT * from user WHERE BOOK2 = '%s' "%(book))
        t=(cursor.fetchall())
        diff=(today-t[0][12]).days
        if diff>0:
            Update3="Update user set DOI2='%s', DOR2='%s',payfine='%s' where BOOK2='%s' " %(today,returndate,t[0][13]+diff*5,book)
            cursor.execute(Update3)
            conn.commit()
            messagebox.askokcancel("Information","you have reissued 2nd book")
    else:
        diff=(today-t[0][9]).days
        if diff>0:
            Update3="Update user set DOI1='%s', DOR1='%s',payfine='%s' where BOOK1='%s' " %(today,returndate,t[0][13]+diff*5,book)
            cursor.execute(Update3)
            conn.commit()
            messagebox.askokcancel("Information","you have reissued 1st book")

image15=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame3.jpg")
image15=image15.resize((1530,800),Image.ANTIALIAS)
img15 = ImageTk.PhotoImage(image15)
panel15 = tk.Label(frame15, image = img15)
panel15.place(relx=0,rely=0)
frame151_label=tk.Label(frame15,text="BOOK_ID").place(relx=0.25,rely=0.2)
frame152_entry=tk.Entry(frame15,textvariable=bookid).place(relx=0.45,rely=0.2)

frame153_buttom=tk.Button(frame15,text="RENEW",command=renew).place(relx=0.35,rely=0.3)
back_button15=tk.Button(frame15,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button15.place(relx=0.5,rely=0.5)

def returnbook():
    today = date.today()
    book=bookid.get()
    cursor.execute("SELECT * from book_details WHERE BOOK_ID = '%s' "%(book))
    v=(cursor.fetchall())
    if v==[]:
        frame144_label.config(text="Wrong BOOK_ID")
    else:
        if v[0][6]==bool(1):
            Update="Update book_details set STATUS='%s' where BOOK_ID='%s'" %(0,book)
            cursor.execute(Update)
            conn.commit()
            cursor.execute("SELECT * from user WHERE BOOK1 = '%s' "%(book))
            t=(cursor.fetchall())
            
            if t==[]:
                cursor.execute("SELECT * from user WHERE BOOK2 = '%s' "%(book))
                t=(cursor.fetchall())
                diff=(today-t[0][12]).days
                Update2="Update user set BOOK2='%s',no_all_book='%s' where USER_ID='%s'" %('0000',t[0][14]-1,t[0][0])
                cursor.execute(Update2)
                conn.commit()
                messagebox.showinfo("Information","FIRST BOOK RETURNED")
                if diff>0:
                    Update3="Update user set payfine='%s' where USER_ID='%s' " %(t[0][13]+diff*5,t[0][0])
                    cursor.execute(Update3)
                    conn.commit()
                    messagebox.showinfo("Information","FIRST BOOK RETURNED")
                    
                
            else:
                diff=(today-t[0][9]).days
                Update2="Update user set BOOK1='%s',no_all_book='%s' where USER_ID='%s'" %('0000',t[0][14]-1,t[0][0])
                cursor.execute(Update2)
                conn.commit()
                messagebox.showinfo("Information","SECOND BOOK RETURNED")
                if diff>0:
                    Update3="Update user set payfine='%s' where USER_ID='%s' " %(t[0][13]+diff*5,t[0][0])
                    cursor.execute(Update3)
                    conn.commit()
                    messagebox.showinfo("Information","SECOND BOOK RETURNED")
                
                

                
image14=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame3.jpg")
image14=image14.resize((1530,800),Image.ANTIALIAS)
img14 = ImageTk.PhotoImage(image14)
panel14 = tk.Label(frame14, image = img14)
panel14.place(relx=0,rely=0)
frame141_label=tk.Label(frame14,text="BOOK_ID").place(relx=0.25,rely=0.2)
frame142_entry=tk.Entry(frame14,textvariable=bookid).place(relx=0.45,rely=0.2)
frame143_button=tk.Button(frame14,text="RETURN",command=returnbook).place(relx=0.35,rely=0.3)
frame144_label=tk.Label(frame14,text="")
frame144_label.place(relx=0.55,rely=0.4)
back_button145=tk.Button(frame14,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button145.place(relx=0.5,rely=0.5)

def data():
    name=name_var.get()
    show_frame(frame20)
    cursor.execute("SELECT * from user WHERE USER_ID = '%s' "%(name))
    t=(cursor.fetchall())
    frame20name_label.config(text=t[0][2])
    frame20user_label.config(text=t[0][0])
    frame20status_label.config(text=t[0][5])
    frame20email_label.config(text=t[0][4])
    frame20mob_label.config(text=t[0][1])
    frame20due_label.config(text=t[0][13])
    if t[0][7]== '0000':
        frame20book1_label.config(text="None\t\t\tNone\t\t\tNone\t\tnone")
    else:
        cursor.execute("SELECT * from book_details WHERE BOOK_ID = '%s' "%(t[0][7]))
        v=(cursor.fetchall())
        frame20book1_label.config(text=str(t[0][7])+"\t\t\t "+v[0][1]+'\t\t\t  '+str(t[0][8])+'\t\t'+str(t[0][9]))
    if t[0][10]== '0000':
        frame20book2_label.config(text="None\t\t\tNone\t\t\tNone\t\tnone")
    else:
        cursor.execute("SELECT * from book_details WHERE BOOK_ID = '%s' "%(t[0][10]))
        v=(cursor.fetchall())
        frame20book2_label.config(text=str(t[0][10])+'\t\t\t'+v[0][1]+'\t\t\t  '+str(t[0][11])+'\t\t'+str(t[0][12]))



def issue(): 
    user=userid.get() 
    book=bookid.get()
    cursor.execute("SELECT * from user WHERE USER_ID = '%s' "%(user))
    t=(cursor.fetchall())
    cursor.execute("SELECT * from book_details WHERE BOOK_ID = '%s' "%(book))
    v=(cursor.fetchall())
    if t[0][14]<2:
        if v[0][6]==bool(0):
            Update="Update book_details set STATUS='%s' where BOOK_ID='%s'" %(1,book)
            cursor.execute(Update)
            conn.commit()
            today = date.today()
            returndate = today + datetime.timedelta(days = 15)
            if  t[0][7]=="0000":
                update2="Update user set BOOK1='%s',DOI1='%s',DOR1='%s',no_all_book='%s' where USER_ID='%s'" %(book,str(today),(returndate),1,user)
            elif t[0][10]=="0000":
                update2="Update user set BOOK2='%s',DOI2='%s',DOR2='%s',no_all_book='%s' where USER_ID='%s'" %(book,str(today),str(returndate),2,user)
            cursor.execute(update2)
            conn.commit()
            frame135_label.config(text="Book Issued")
        else:
            messagebox.askokcancel("Information","This book is already issued to someone! ")
            
    else:
        messagebox.askokcancel("Information","sorry already 2 book issued")

        
        
image13=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame5.jpg")
image13=image13.resize((1530,800),Image.ANTIALIAS)
img13 = ImageTk.PhotoImage(image13)
panel13 = tk.Label(frame13, image = img13)
panel13.place(relx=0,rely=0)
frame131_label=tk.Label(frame13,text="USER_ID").place(relx=0.35,rely=0.1)
frame132_label=tk.Label(frame13,text="BOOK_ID").place(relx=0.35,rely=0.2)
frame133_entry=tk.Entry(frame13,textvariable=userid).place(relx=0.55,rely=0.1)
frame134_entry=tk.Entry(frame13,textvariable=bookid).place(relx=0.55,rely=0.2)
frame135_label=tk.Label(frame13,text="")
frame135_label.place(relx=0.4,rely=0.4)
frame136_buttom=tk.Button(frame13,text="ISSUE",command=issue).place(relx=0.45,rely=0.3)
back_button137=tk.Button(frame13,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button137.place(relx=0.5,rely=0.5)

def ShowRecord():
    frame111_label=tk.Label(frame11,text="TITLE",width=15,height=2,bg="pink").place(relx=0.31,rely=0.3)
    frame112_label=tk.Label(frame11,text="AUTHOR",width=15,height=2,bg="pink").place(relx=0.31,rely=0.4)
    frame113_label=tk.Label(frame11,text="EDITION",width=15,height=2,bg="pink").place(relx=0.31,rely=0.5)
    frame114_label=tk.Label(frame11,text="PRICE",width=15,height=2,bg="pink").place(relx=0.31,rely=0.6)
    

    BOOK_ID=frame111_entry.get()
    dbBOOK_ID=""
    Select="select BOOK_ID from book_details where BOOK_ID='%s'" %(BOOK_ID)
    cursor.execute(Select)
    result1=cursor.fetchall()
    for i in result1:
        dbBOOK_ID=i[0]
    Select1="select TITLE,AUTHOR,EDITION,PRICE from book_details where BOOK_ID='%s'" %(BOOK_ID)
    cursor.execute(Select1)
    result2=cursor.fetchall()
    TITLE=""
    AUTHOR=""
    EDITION=""
    PRICE=""
    if(int(BOOK_ID) == dbBOOK_ID):
        for i in result2:
            TITLE=i[0]
            AUTHOR=i[1]
            EDITION=i[2]
            PRICE=i[3]
        frame115_label=tk.Label(frame11,text=TITLE,width=20,height=2,bg="pink").place(relx=0.46,rely=0.3)
        frame117_label=tk.Label(frame11,text=AUTHOR,width=20,height=2,bg="pink").place(relx=0.46,rely=0.4)
        frame118_label=tk.Label(frame11,text=EDITION,width=20,height=2,bg="pink").place(relx=0.46,rely=0.5)
        frame119_label=tk.Label(frame11,text=PRICE,width=20,height=2,bg="pink").place(relx=0.46,rely=0.6)
        
        
    else:
        messagebox.askokcancel("Information","No Record exists")

def Updatel():
    frame121_label=tk.Label(frame12,text="BOOK_ID",width=20,height=2,bg="pink").place(relx=0.35,rely=0.2)
    frame122_label=tk.Label(frame12,text="TITLE",width=20,height=2,bg="pink").place(relx=0.35,rely=0.3)
    frame123_label=tk.Label(frame12,text="AUTHOR",width=20,height=2,bg="pink").place(relx=0.35,rely=0.4)
    frame124_label=tk.Label(frame12,text="EDITION",width=20,height=2,bg="pink").place(relx=0.35,rely=0.5)
    frame125_label=tk.Label(frame12,text="PRICE",width=20,height=2,bg="pink").place(relx=0.35,rely=0.6)
    BOOK_ID=frame128_entry.get()
    TITLE=frame129_entry.get()
    AUTHOR=frame1210_entry.get()
    EDITION=frame1211_entry.get()
    PRICE=frame1212_entry.get()
    Update="Update book_details set TITLE='%s', AUTHOR='%s', EDITION='%s', PRICE='%s' where BOOK_ID='%s'" %(TITLE,AUTHOR,EDITION,PRICE,BOOK_ID)
    cursor.execute(Update)
    conn.commit()
    messagebox.showinfo("Info","RECORD UPDATED")


image12=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame4.jpg")
image12=image12.resize((1530,800),Image.ANTIALIAS)
img12 = ImageTk.PhotoImage(image12)
panel12 = tk.Label(frame12, image = img12)
panel12.place(relx=0,rely=0)
frame121_label=tk.Label(frame12,text="BOOK_ID",width=20,height=2,bg="pink").place(relx=0.35,rely=0.2)
frame122_label=tk.Label(frame12,text="TITLE",width=20,height=2,bg="pink").place(relx=0.35,rely=0.3)
frame123_label=tk.Label(frame12,text="AUTHOR",width=20,height=2,bg="pink").place(relx=0.35,rely=0.4)
frame124_label=tk.Label(frame12,text="EDITION",width=20,height=2,bg="pink").place(relx=0.35,rely=0.5)
frame125_label=tk.Label(frame12,text="PRICE",width=20,height=2,bg="pink").place(relx=0.35,rely=0.6)
frame128_entry=tk.Entry(frame12,width=30,borderwidth=8)
frame128_entry.place(relx=0.55,rely=0.2)
frame129_entry=tk.Entry(frame12,width=30,borderwidth=8)
frame129_entry.place(relx=0.55,rely=0.3)
frame1210_entry=tk.Entry(frame12,width=30,borderwidth=8)
frame1210_entry.place(relx=0.55,rely=0.4)
frame1211_entry=tk.Entry(frame12,width=30,borderwidth=8)
frame1211_entry.place(relx=0.55,rely=0.5)
frame1212_entry=tk.Entry(frame12,width=30,borderwidth=8)
frame1212_entry.place(relx=0.55,rely=0.6)
frame1214_button=tk.Button(frame12,text="UPDATE",width=10,height=2,command=Updatel).place(relx=0.47,rely=0.7)
   
back_button1241=tk.Button(frame12,text="BACK",width=5,height=2,command=lambda:show_frame(frame11))
back_button1241.place(relx=0.48,rely=0.8)


image11=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame3.jpg")
image11=image11.resize((1530,800),Image.ANTIALIAS)
img11 = ImageTk.PhotoImage(image11)
panel11 = tk.Label(frame11, image = img11)
panel11.place(relx=0,rely=0)
frame1110_label=tk.Label(frame11,text="BOOK_ID",width=15,height=2,bg="pink").place(relx=0.31,rely=0.2)
frame111_entry=tk.Entry(frame11,width=30,borderwidth=20)
frame111_entry.place(relx=0.45,rely=0.2)
frame1111_button=tk.Button(frame11,text="SHOW",width=10,height=2,command=ShowRecord).place(relx=0.7,rely=0.25)
frmae1112_button=tk.Button(frame11,text="EDIT BOOK",width=10,height=2,command=lambda:show_frame(frame12)).place(relx=0.7,rely=0.35)
back_button1141=tk.Button(frame11,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button1141.place(relx=0.6,rely=0.6)

def Showlist():
    frame111_label=tk.Label(frame18,text="TITLE",width=15,height=2,bg="pink").place(relx=0.31,rely=0.3)
    frame112_label=tk.Label(frame18,text="AUTHOR",width=15,height=2,bg="pink").place(relx=0.31,rely=0.4)
    frame113_label=tk.Label(frame18,text="EDITION",width=15,height=2,bg="pink").place(relx=0.31,rely=0.5)
    frame114_label=tk.Label(frame18,text="PRICE",width=15,height=2,bg="pink").place(relx=0.31,rely=0.6)
    

    BOOK_ID=frame181_entry.get()
    dbBOOK_ID=""
    Select="select BOOK_ID from book_details where BOOK_ID='%s'" %(BOOK_ID)
    cursor.execute(Select)
    result1=cursor.fetchall()
    for i in result1:
        dbBOOK_ID=i[0]
    Select1="select TITLE,AUTHOR,EDITION,PRICE from book_details where BOOK_ID='%s'" %(BOOK_ID)
    cursor.execute(Select1)
    result2=cursor.fetchall()
    TITLE=""
    AUTHOR=""
    EDITION=""
    PRICE=""
    if(int(BOOK_ID) == dbBOOK_ID):
        for i in result2:
            TITLE=i[0]
            AUTHOR=i[1]
            EDITION=i[2]
            PRICE=i[3]
        frame115_label=tk.Label(frame18,text=TITLE,width=20,height=2,bg="pink").place(relx=0.46,rely=0.3)
        frame117_label=tk.Label(frame18,text=AUTHOR,width=20,height=2,bg="pink").place(relx=0.46,rely=0.4)
        frame118_label=tk.Label(frame18,text=EDITION,width=20,height=2,bg="pink").place(relx=0.46,rely=0.5)
        frame119_label=tk.Label(frame18,text=PRICE,width=20,height=2,bg="pink").place(relx=0.46,rely=0.6)
        
        
    else:
        messagebox.askokcancel("Information","No Record exists")
        
image18=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame3.jpg")
image18=image18.resize((1530,800),Image.ANTIALIAS)
img18 = ImageTk.PhotoImage(image18)
panel18 = tk.Label(frame18, image = img18)
panel18.place(relx=0,rely=0)
frame1810_label=tk.Label(frame18,text="BOOK_ID",width=15,height=2,bg="pink").place(relx=0.31,rely=0.2)
frame181_entry=tk.Entry(frame18,width=30,borderwidth=20)
frame181_entry.place(relx=0.45,rely=0.2)
frame1811_button=tk.Button(frame18,text="SHOW",width=10,height=2,command=Showlist).place(relx=0.7,rely=0.25)
back_button1841=tk.Button(frame18,text="BACK",width=5,height=2,command=lambda:show_frame(frame17))
back_button1841.place(relx=0.6,rely=0.6)

def forgot(): 
    username=name_var.get()  
    cursor.execute("SELECT * from user WHERE USER_ID = '%s' "%(username))
    t=(cursor.fetchall())
    try:
        if t[0][0]!='\0':
            OTP = random.randint(100000,999999)
            s=smtplib.SMTP('smtp.gmail.com',587)
            s.starttls()
            s.login("rishabhluharuka@gmail.com","Monster@95")
            s.sendmail("rishabhluharuka@gmail.com",t[0][4],str(OTP))
            s.quit()
            Update="Update user set OTP='%d' where USER_ID='%s'" %(OTP,username)
            cursor.execute(Update)
            conn.commit()
            frame13_label.config(text="USERNAME found")
            show_frame(frame9)
    except IndexError:
        frame13_label.config(text="USERNAME not found")

def otp_verification():
    username=name_var.get()
    OTP=otp.get()
    
    cursor.execute("SELECT * from user WHERE USER_ID = '%s' "%(username))
    t=(cursor.fetchall())
    if t[0][6]==int(OTP):
        show_frame(frame10)
    else:
        frame93_label.config(text="OTP wrong")
        

image9=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame5.jpg")
image9=image9.resize((1530,800),Image.ANTIALIAS)
img9 = ImageTk.PhotoImage(image9)
panel9 = tk.Label(frame9, image = img9)
panel9.place(relx=0,rely=0)
frame9_title=tk.Label(frame9,text='LIBRARY MANAGEMENT SYSTEM',bg='red',font=20)
frame9_title.pack(fill='x')
frame9_upper_title=tk.Label(frame9,text="OTP is sent to your email").place(relx=0.3,rely=0.1)
frame91_label=tk.Label(frame9,text="OTP",font=20)
frame91_label.place(relx=0.3,rely=0.2)
frame91_entry=tk.Entry(frame9,textvariable=otp)
frame91_entry.place(relx=0.5,rely=0.2)
frame93_label=tk.Label(frame9,text="",font=20)
frame93_label.place(relx=0.45,rely=0.7)
frame91_btn1 = tk.Button(frame9,text='SUBMIT',command=otp_verification)
frame91_btn1.place(relx=0.5,rely=0.5)
frame92_btn2=tk.Button(frame9,text='BACK',command=lambda:show_frame(frame1))

def replace_password():
    username=name_var.get()
    new=newpass.get()
    rnew=rnewpass.get()
    if new==rnew:
        Update="Update user set PASSWORD='%s' where USER_ID='%s'" %(new,username)
        cursor.execute(Update)
        conn.commit()
        frame103_label.config(text="PASSWORD reset successfully")
    else:
        frame103_label.config(text='Please enter same password')


        
image10=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame4.jpg")
image10=image10.resize((1530,800),Image.ANTIALIAS)
img10 = ImageTk.PhotoImage(image10)
panel10 = tk.Label(frame10, image = img10)
panel10.place(relx=0,rely=0)        
frame10_title=tk.Label(frame10,text='LIBRARY MANAGEMENT SYSTEM',bg='red',font=20)
frame10_title.pack(fill='x')
frame101_label=tk.Label(frame10,text="NEW PASSWORD",font=20)
frame101_label.place(relx=0.3,rely=0.2)

frame102_label=tk.Label(frame10,text="RE-ENTER NEW PASSWORD",font=20)
frame102_label.place(relx=0.3,rely=0.3)

frame101_entry=tk.Entry(frame10,textvariable=newpass,show='*')
frame101_entry.place(relx=0.5,rely=0.2)

frame102_entry=tk.Entry(frame10,textvariable=rnewpass,show='*')
frame102_entry.place(relx=0.5,rely=0.3)

frame103_label=tk.Label(frame10,text="",font=20)
frame103_label.place(relx=0.45,rely=0.5)
frame101_btn1 = tk.Button(frame10,text='SAVE',command=replace_password)
frame101_btn1.place(relx=0.5,rely=0.4)
frame104_btn2=tk.Button(frame10,text='EXIT',command=lambda:show_frame(frame1)).place(relx=0.5,rely=0.6)


image7=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame4.jpg")
image7=image7.resize((1530,800),Image.ANTIALIAS)
img7 = ImageTk.PhotoImage(image7)
panel7 = tk.Label(frame7, image = img7)
panel7.place(relx=0,rely=0)
frame71_label=tk.Label(frame7,text="BOOK_ID",width=20,height=2,bg="pink").place(relx=0.35,rely=0.2)
frame72_label=tk.Label(frame7,text="TITLE",width=20,height=2,bg="pink").place(relx=0.35,rely=0.3)
frame73_label=tk.Label(frame7,text="AUTHOR",width=20,height=2,bg="pink").place(relx=0.35,rely=0.4)
frame74_label=tk.Label(frame7,text="EDITION",width=20,height=2,bg="pink").place(relx=0.35,rely=0.5)
frame75_label=tk.Label(frame7,text="PRICE",width=20,height=2,bg="pink").place(relx=0.35,rely=0.6)
frame76_label=tk.Label(frame7,text="PIECES",width=20,height=2,bg="pink").place(relx=0.35,rely=0.7)


frame78_entry=tk.Entry(frame7,width=30,borderwidth=8)
frame78_entry.place(relx=0.55,rely=0.2)
frame79_entry=tk.Entry(frame7,width=30,borderwidth=8)
frame79_entry.place(relx=0.55,rely=0.3)
frame710_entry=tk.Entry(frame7,width=30,borderwidth=8)
frame710_entry.place(relx=0.55,rely=0.4)
frame711_entry=tk.Entry(frame7,width=30,borderwidth=8)
frame711_entry.place(relx=0.55,rely=0.5)
frame712_entry=tk.Entry(frame7,width=30,borderwidth=8)
frame712_entry.place(relx=0.55,rely=0.6)
frame713_entry=tk.Entry(frame7,width=30,borderwidth=8)
frame713_entry.place(relx=0.55,rely=0.7)

def Update():
    BOOK_ID=frame78_entry.get()
    TITLE=frame79_entry.get()
    AUTHOR=frame710_entry.get()
    EDITION=frame711_entry.get()
    PRICE=frame712_entry.get()
    PIECES=frame713_entry.get()
    Update="Update book_details set TITLE='%s', AUTHOR='%s', EDITION='%s', PRICE='%s', PIECES='%s' where BOOK_ID='%s'" %(TITLE,AUTHOR,EDITION,PRICE,PIECES,BOOK_ID)
    cursor.execute(Update)
    conn.commit()
    messagebox.showinfo("Info","Record Update")

frame714_button=tk.Button(frame7,text="UPDATE",width=10,height=2,command=Update).place(relx=0.5,rely=0.8)
back_button71=tk.Button(frame7,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button71.place(relx=0.51,rely=0.9)

def Showall():
    class A(Frame):
        def __init__(self, parent):
            Frame.__init__(self, parent)
            self.CreateUI()
            self.LoadTable()
            self.grid(sticky=(N, S, W, E))
            parent.grid_rowconfigure(0, weight=1)
            parent.grid_columnconfigure(0, weight=1)
        def CreateUI(self):
            tv= Treeview(self)
            tv['columns']=('BOOK_ID', 'TITLE', 'AUTHOR', 'EDITION', 'PRICE', 'PIECES','STATUS')
            tv.heading('#0',text='BOOK_ID',anchor='center')
            tv.column('#0',anchor='center')
            tv.heading('#1', text='TITLE', anchor='center')
            tv.column('#1', anchor='center')
            tv.heading('#2', text='AUTHOR', anchor='center')
            tv.column('#2', anchor='center')
            tv.heading('#3', text='EDITION', anchor='center')
            tv.column('#3', anchor='center')
            tv.heading('#4', text='PRICE', anchor='center')
            tv.column('#4', anchor='center')
            tv.heading('#5', text='PIECES', anchor='center')
            tv.column('#5', anchor='center')
            tv.heading('#6', text='ISSUED', anchor='center')
            tv.column('#6', anchor='center')
            tv.grid(sticky=(N,S,W,E))
            self.treeview = tv
            self.grid_rowconfigure(0,weight=1)
            self.grid_columnconfigure(0,weight=1)
        def LoadTable(self):
            Select="Select * from book_details"
            cursor.execute(Select)
            result=cursor.fetchall()
            BOOK_ID=""
            TITLE=""
            AUTHOR=""
            EDITION=""
            PRICE=""
            PIECES=""
            STATUS=""
            for i in result:
                BOOK_ID=i[0]
                TITLE=i[1]
                AUTHOR=i[2]
                EDITION=i[3]
                PRICE=i[4]
                PIECES=i[5]
                STATUS=i[6]
                self.treeview.insert("",'end',text=BOOK_ID,values=(TITLE,AUTHOR,EDITION,PRICE,PIECES,STATUS))
    frame6=Tk()
    frame6.title("Overview Page")
    A(frame6)

frame61_button5=Button(frame6,text="BOOK RECORD",width=10,height=2,command=Showall).grid(row=7,column=7)
back_button61=tk.Button(frame6,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button61.place(relx=0.5,rely=0.5)

def Delete():
    BOOK_ID=frame51_entry.get()
    Delete="delete from book_details where BOOK_ID='%s'" %(BOOK_ID)
    cursor.execute(Delete)
    conn.commit()
    messagebox.showinfo("Information","Record Deleted")
    frame51_entry.delete(0,END)

def Register():
    BOOK_ID=frame41_entry.get()
    Select="select BOOK_ID from book_details where BOOK_ID='%s'" %(BOOK_ID)
    cursor.execute(Select)
    result=cursor.fetchall()
    if result!=[]:
        messagebox.askokcancel("Information","Record Already exists")
    else:
        Insert="Insert into book_details(BOOK_ID,TITLE,AUTHOR,EDITION,PRICE,STATUS) values(%s,%s,%s,%s,%s,0)"
        TITLE=frame42_entry.get()
        AUTHOR=frame43_entry.get()
        EDITION=frame44_entry.get()
        PRICE=frame45_entry.get()
        
        if(TITLE !="" and AUTHOR !="" and EDITION !="" and PRICE !="" ):
            Value=(BOOK_ID,TITLE,AUTHOR,EDITION,PRICE)
            cursor.execute(Insert,Value)
            conn.commit()
            messagebox.askokcancel("Information","Record inserted")
            frame41_entry.delete(0, END)
            frame42_entry.delete(0, END)
            frame43_entry.delete(0, END)
            frame44_entry.delete(0, END)
            frame45_entry.delete(0, END)
        else:
            if (TITLE == "" and AUTHOR == "" and EDITION == "" and PRICE == ""  ):
                messagebox.askokcancel("Information","New Entery Fill All Details")
            else:
                messagebox.askokcancel("Information", "Some fields left blank")
        

def show_frame(frame):
    frame.tkraise()

    
def login(): 
  
    name=name_var.get() 
    password=passw_var.get()
    
    
    cursor.execute("SELECT * from user WHERE USER_ID = '%s' "%(name))
    t=(cursor.fetchall())
    
    
    try:
        if t[0][3]==password:
            frame13_label.config(text="Successfull")
            if t[0][5]=='Admin':
                show_frame(frame2)
            elif t[0][5]=='Student':
                show_frame(frame17)
                frame17name_label.config(text=t[0][2])
                frame17user_label.config(text=t[0][0])
                frame17status_label.config(text=t[0][5])
                frame17email_label.config(text=t[0][4])
                frame17mob_label.config(text=t[0][1])
                frame17due_label.config(text=t[0][13])
                if t[0][7]== '0000':
                    frame17book1_label.config(text="None\t\t\tNone\t\t\tNone\t\tnone")
                else:
                    cursor.execute("SELECT * from book_details WHERE BOOK_ID = '%s' "%(t[0][7]))
                    v=(cursor.fetchall())
                    frame17book1_label.config(text=str(t[0][7])+"\t\t\t "+v[0][1]+'\t\t\t  '+str(t[0][8])+'\t\t'+str(t[0][9]))
                if t[0][10]== '0000':
                    frame17book2_label.config(text="None\t\t\tNone\t\t\tNone\t\tnone")
                else:
                    cursor.execute("SELECT * from book_details WHERE BOOK_ID = '%s' "%(t[0][10]))
                    v=(cursor.fetchall())
                    frame17book2_label.config(text=str(t[0][10])+'\t\t\t'+v[0][1]+'\t\t\t  '+str(t[0][11])+'\t\t'+str(t[0][12]))
        else:
            frame13_label.config(text="Wrong password")
    except IndexError:
        frame13_label.config(text="USERNAME not found")
        
        

image=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\FRAME1.jpg")
image=image.resize((1530,800),Image.ANTIALIAS)
img = ImageTk.PhotoImage(image)
panel = tk.Label(frame1, image = img)
panel.place(relx=0,rely=0)
frame1_title=tk.Label(frame1,text='LIBRARY MANAGEMENT SYSTEM',bg='red',font=20)
frame1_title.pack(fill='x')
frame11_entry=tk.Entry(frame1,textvariable=name_var,)
frame11_entry.place(relx=0.8,rely=0.435)
frame12_entry=tk.Entry(frame1,textvariable=passw_var,show='*')
frame12_entry.place(relx=0.8,rely=0.535)
frame11_btn1 = tk.Button(frame1,text='LOGIN',command=login,bg='white')
frame11_btn1.place(relx=0.7,rely=0.65)
frame12_btn2 = tk.Button(frame1,text='FORGOT PASSWORD',command=forgot,bg='white')
frame12_btn2.place(relx=0.825,rely=0.65)
frame13_label=tk.Label(frame1,text="",font=20,bg='white')
frame13_label.place(relx=0.73,rely=0.75,)








image2=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame41.jpg")
image2=image2.resize((1530,800),Image.ANTIALIAS)
img2 = ImageTk.PhotoImage(image2)
panel2 = tk.Label(frame2, image = img2)
panel2.place(relx=0,rely=0)
frame21_label = tk.Label(frame2,text="DASHBOARD",width=20,height=1,font=20)
frame211_button = tk.Button(frame2,text="PROFILE",width=8,height=2,command=data)
frame21_button = tk.Button(frame2, text="ADD BOOKS",width=15,height=2,command=lambda:show_frame(frame4))
frame22_button = tk.Button(frame2, text="EDIT BOOKS",width=15,height=2,command=lambda:show_frame(frame7))
frame23_button = tk.Button(frame2, text="ISSUE BOOKS",width=15,height=2,command=lambda:show_frame(frame13))
frame24_button = tk.Button(frame2, text="RETURN BOOKS",width=15,height=2,command=lambda:show_frame(frame14))
frame25_button = tk.Button(frame2, text="DELETE BOOKS",width=15,height=2,command=lambda:show_frame(frame5))
frame26_button = tk.Button(frame2, text="SHOW BOOKS",width=15,height=2,command=Showall)
frame27_button = tk.Button(frame2, text="SEARCH BOOKS",width=15,height=2,command=lambda:show_frame(frame11))
frame28_button = tk.Button(frame2, text="RENEW BOOKS",width=15,height=2,command=lambda:show_frame(frame15))
frame29_button = tk.Button(frame2, text="PAY FINE",width=15,height=2,command=lambda:show_frame(frame16))
frame210_button = tk.Button(frame2, text="LOGOUT",width=15,height=2,command=logout)
back_button1=tk.Button(frame2,text="BACK",width=5,height=2,command=lambda:show_frame(frame1))
frame21_label.place(relx=0.42,rely=0.1)
frame211_button.place(relx=0.1,rely=0.1)
frame21_button.place(relx=0.25,rely=0.2)
frame22_button.place(relx=0.25,rely=0.3)
frame23_button.place(relx=0.25,rely=0.4)
frame24_button.place(relx=0.25,rely=0.5)
frame25_button.place(relx=0.25,rely=0.6)
frame26_button.place(relx=0.7,rely=0.2)
frame27_button.place(relx=0.7,rely=0.3)
frame28_button.place(relx=0.7,rely=0.4)
frame29_button.place(relx=0.7,rely=0.5)
frame210_button.place(relx=0.7,rely=0.6)
back_button1.place(relx=0.5,rely=0.8)

frame3_title=tk.Label(frame3,text='this is frame3',bg='green')
frame3_title.pack(fill='x')
frame3_btn = tk.Button(frame3,text='enter',command=lambda:show_frame(frame1))
frame3_btn.pack()


image3=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame4.jpg")
image3=image3.resize((1530,800),Image.ANTIALIAS)
img3 = ImageTk.PhotoImage(image3)
panel3 = tk.Label(frame4, image = img3)
panel3.place(relx=0,rely=0)
frame41_label=tk.Label(frame4,text="BOOK_ID",width=20,height=2,bg="pink")
frame41_label.place(relx=0.35,rely=0.2)
frame42_label=tk.Label(frame4,text="TITLE",width=20,height=2,bg="pink")
frame42_label.place(relx=0.35,rely=0.3)
frame43_label=tk.Label(frame4,text="AUTHOR",width=20,height=2,bg="pink")
frame43_label.place(relx=0.35,rely=0.4)
frame44_label=tk.Label(frame4,text="EDITION",width=20,height=2,bg="pink")
frame44_label.place(relx=0.35,rely=0.5)
frame45_label=tk.Label(frame4,text="PRICE",width=20,height=2,bg="pink")
frame45_label.place(relx=0.35,rely=0.6)
back_button41=tk.Button(frame4,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button41.place(relx=0.51,rely=0.8)
frame41_entry=tk.Entry(frame4,width=30,borderwidth=8)
frame41_entry.place(relx=0.55,rely=0.2)
frame42_entry=tk.Entry(frame4,width=30,borderwidth=8)
frame42_entry.place(relx=0.55,rely=0.3)
frame43_entry=tk.Entry(frame4,width=30,borderwidth=8)
frame43_entry.place(relx=0.55,rely=0.4)
frame44_entry=tk.Entry(frame4,width=30,borderwidth=8)
frame44_entry.place(relx=0.55,rely=0.5)
frame45_entry=tk.Entry(frame4,width=30,borderwidth=8)
frame45_entry.place(relx=0.55,rely=0.6)
frame42_button=tk.Button(frame4,text="REGISTER",width=10,height=2,command=Register).place(relx=0.5,rely=0.7)




image5=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame3.jpg")
image5=image5.resize((1530,800),Image.ANTIALIAS)
img5 = ImageTk.PhotoImage(image5)
panel5 = tk.Label(frame5, image = img5)
panel5.place(relx=0,rely=0)
frame51_label=tk.Label(frame5,text="BOOK_ID",width=20,height=2,bg="pink")
frame51_label.place(relx=0.31,rely=0.3)
frame51_entry=tk.Entry(frame5,width=30,borderwidth=8)
frame51_entry.place(relx=0.49,rely=0.3)
frame51_button=tk.Button(frame5,text="DELETE",width=10,height=2,command=Delete)
frame51_button.place(relx=0.45,rely=0.52)
back_button51=tk.Button(frame5,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button51.place(relx=0.46,rely=0.6)


image17=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame6.jpg")
image17=image17.resize((1530,800),Image.ANTIALIAS)
img17 = ImageTk.PhotoImage(image17)
panel17 = tk.Label(frame17, image = img17)
panel17.place(relx=0,rely=0)
frame171_label = tk.Label(frame17,text="DASHBOARD",width=20,height=1,font=20)
frame176_button = tk.Button(frame17, text="SHOW BOOKS",width=15,height=2,command=Showall)
frame177_button = tk.Button(frame17, text="SEARCH BOOKS",width=15,height=2,command=lambda:show_frame(frame18))
frame179_button = tk.Button(frame17, text="PAY FINE",width=15,height=2,command=lambda:show_frame(frame19))
frame1710_button = tk.Button(frame17, text="LOGOUT",width=15,height=2,command=logout)
frame171_label.place(relx=0.42,rely=0.1)
frame176_button.place(relx=0.2,rely=0.2)
frame177_button.place(relx=0.4,rely=0.2)
frame179_button.place(relx=0.6,rely=0.2)
frame1710_button.place(relx=0.8,rely=0.2)
frame17name_label = tk.Label(frame17,text="",width=30,height=1,font=22,bg='white')
frame17name_label.place(relx=0.25,rely=0.41)
frame17user_label = tk.Label(frame17,text="",width=30,height=1,font=22,bg='white')
frame17user_label.place(relx=0.25,rely=0.465)
frame17status_label = tk.Label(frame17,text="",width=30,height=1,font=22,bg='white')
frame17status_label.place(relx=0.62,rely=0.465)
frame17email_label = tk.Label(frame17,text="",width=30,height=1,font=22,bg='white')
frame17email_label.place(relx=0.25,rely=0.52)
frame17mob_label = tk.Label(frame17,text="",width=30,height=1,font=22,bg='white')
frame17mob_label.place(relx=0.62,rely=0.52)
frame17book1_label = tk.Label(frame17,text="",width=110,height=1,font=22,bg='white')
frame17book1_label.place(relx=0.1,rely=0.65)
frame17book2_label = tk.Label(frame17,text="",width=110,height=1,font=22,bg='white')
frame17book2_label.place(relx=0.1,rely=0.725)
frame17due_label = tk.Label(frame17,text="",width=20,height=1,font=22,bg='white')
frame17due_label.place(relx=0.2,rely=0.83)


image20=Image.open("C:\\Users\\RISHABH LUHARUKA\\Downloads\\frame20.jpg")
image20=image20.resize((1530,800),Image.ANTIALIAS)
img20 = ImageTk.PhotoImage(image20)
panel20 = tk.Label(frame20, image = img20)
panel20.place(relx=0,rely=0)
frame20name_label = tk.Label(frame20,text="",width=30,height=1,font=22,bg='white')
frame20name_label.place(relx=0.25,rely=0.41)
frame20user_label = tk.Label(frame20,text="",width=30,height=1,font=22,bg='white')
frame20user_label.place(relx=0.25,rely=0.465)
frame20status_label = tk.Label(frame20,text="",width=30,height=1,font=22,bg='white')
frame20status_label.place(relx=0.62,rely=0.465)
frame20email_label = tk.Label(frame20,text="",width=30,height=1,font=22,bg='white')
frame20email_label.place(relx=0.25,rely=0.52)
frame20mob_label = tk.Label(frame20,text="",width=30,height=1,font=22,bg='white')
frame20mob_label.place(relx=0.62,rely=0.52)
frame20book1_label = tk.Label(frame20,text="",width=110,height=1,font=22,bg='white')
frame20book1_label.place(relx=0.1,rely=0.65)
frame20book2_label = tk.Label(frame20,text="",width=110,height=1,font=22,bg='white')
frame20book2_label.place(relx=0.1,rely=0.725)
frame20due_label = tk.Label(frame20,text="",width=20,height=1,font=22,bg='white')
frame20due_label.place(relx=0.2,rely=0.83)
back_button20=tk.Button(frame20,text="BACK",width=5,height=2,command=lambda:show_frame(frame2))
back_button20.place(relx=0.9,rely=0.9)


show_frame(frame1)
window.mainloop()
conn.close()
